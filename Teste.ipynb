# %% [markdown]
# <a href="https://colab.research.google.com/github/SrLiloca/Atividades-/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# 1. Carregar Dataset (usando o Iris como exemplo)
iris = load_iris()
X = iris.data  # Características
y = iris.target # Alvo (Classes)

# 2. Dividir em Treino e Teste
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=0
)

# 3. Criar e Treinar o Modelo
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# 4. Fazer Previsões
y_pred = gnb.predict(X_test)

# 5. Avaliar o Modelo
print("--- Avaliação do Naive Bayes Gaussiano ---")
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print("\nRelatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
# --- Avaliação do Naive Bayes Gaussiano ---
# Acurácia: 0.9333
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.85      1.00      0.92        23
#            2       1.00      0.81      0.89        21
#
#     accuracy                           0.93        60
#    macro avg       0.95      0.94      0.94        60
# weighted avg       0.94      0.93      0.93        60
